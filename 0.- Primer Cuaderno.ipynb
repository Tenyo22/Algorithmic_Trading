# %% [markdown]
# # Texto
# # Encabezado 1
# ## Encabezado 2
# ### Encabezado 3
# #### Encabezado 4
#
# Parrafo
#
# **Negrita**
#
# *Cursiva*
#
# ***Negrita + Cursiva***

# %% [markdown]
# # Cargando Paquetes/Librerias

# %%
import pandas
import numpy as np

# %% [markdown]
# # Informacion sobre un methodo (Docstring)

# %%
# info (docstring) about a method
np.random?

# %% [markdown]
# # Usando Nuevos Paquetes /Librerias

# %%
# Libreria Financiera que nos ayuda a obtener datos financieros
# Stocks, Futuros, Forex...
import quandl as qd

# %%
pip install quandl

# %%
import quandl as qd

# %% [markdown]
# # Montando Drive

# %%
# El drive es el espacio en disco de la cuenta Gmail
# Util para guardar carpetas, documentos, archivos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Mostrar Imagenes

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/Colab Notebooks/Python - Image.png')

# %% [markdown]
# # Inspector de Variables
# ##### Usando los "magic comands" ***who*** y ***whos***

# %%
x = [1,2,3,4]
y = "Hello Python"
z = 1.2

# %%
# Para saber cuales son las variables que tenemos creadas
who

# %%
# Para saber que hay en cada variable
whos
# Out:
# No variables match your requested type.
